# %%
import torch
from dataset import TextDataset

# %%
def one_hot(batch, vocab_size):

    X = torch.zeros(batch.shape[0], batch.shape[1], vocab_size, device=batch.device)
    X.scatter_(2, batch[:,:,None], 1)

    return X

def sample_output(output, temperature=1.0):
    # helper function to sample an index from a probability array

    output = torch.softmax(output, dim=1) / temperature
    sample = torch.multinomial(output, 1)
    
    return sample

def sample_model(model, vocab_size, device=torch.device('cpu'), temp=1.0, hidden_states=None, n=30, prev_char=None):

    if n == 0:
        return prev_char

    # initialize sequence with random character
    if prev_char is None:
        # random character seed
        prev_char = torch.empty(1, 1).random_(0, vocab_size - 1).type(torch.long)
        # convert to one-hot
        prev_char = one_hot(prev_char, vocab_size).to(device)

    output, hidden_states = model(prev_char, hidden_states)
    output = output[:, -1, :] # last prediction

    # Sample next character from softmax
    next_char = sample_output(output, temperature=temp)  # [B,1]
    next_char = one_hot(next_char, vocab_size)           # [B,1,D]

    # concat the recursive predictions to currect character
    future = sample_model(model, vocab_size, temp=temp, hidden_states=hidden_states, n=n-1, prev_char=next_char)
    encoded_text = torch.cat([next_char, future], dim=1)

    return encoded_text

def string_from_one_hot(sequence, dataset, unk=0):
    char_idxs = sequence.argmax(dim=2).squeeze_(0).cpu().numpy()
    return dataset.convert_to_string([char if char < dataset.vocab_size else unk for char in char_idxs])

# %%
def sample_for_epoch(epoch, dataset, n=5, temp=1.0, unk=0):
    
    model = torch.load('grimm/grimm_epoch_{}.pt'.format(epoch),map_location=lambda storage, loc: storage)

    print()
    print("Unkown char:", dataset.convert_to_string([unk]))
    
    samples = []
    for i in range(n):
        chars = sample_model(model, model.out_projection.out_features, temp=temp, n=300)
        sample = string_from_one_hot(chars, dataset)
        
        print("----------")
        print(sample)

# %%
dataset = TextDataset('assets/book_EN_grimms_fairy_tails.txt', 30)

for ep in range(0, 21, 5):
    if ep == 0:
        ep += 1
    print()
    print()
    print("Samples for epoch {}".format(ep))
    print()
    sample_for_epoch(ep,dataset, n=5, unk=43, temp=0.00001)
# Out:
# Initialize dataset with 540241 characters, 87 unique.
#
#
# Samples for epoch 1
#
#
# Unkown char: Q
# ----------
# arried the door
# and stook a choose that morning. He heard them with its for a large prisonor journey, and tied on their dear asks for her;
# but they certains is with theirn again, but the tempt of all.
#
# The princesses were sinten he agree door, and she went with
# her.
# ‘’They doord not agrow there, frr
# ----------
# ND TAR HIP  Ther Sicks there were
# dear son their
# new griefnes.
# ‘“ Soon after ask: and when
# he he
# spring again again. So the king came and one peas me some of the door, and
# they weak to
# do see now;
# for I dear for shee in his peace.
#
# ‘’I am joytiged twop, found the daumfs again.
# ‘“ The king take his bb
# ----------
# ther
# ever seeit door. At last, asks for the girl path again, and as he came to let up, behine one of their door alron with asks for the
# hes.
# ‘“ The king said:
# ‘’Ild and the beautiful
# princesss for the task-door, and had eatour on the
# foucarrared their wing until it all upon their feet of it
# agrove..
# ----------
#  of the other princes and wood at their
# princess, and took his head again
# their head for the house, so that she drove? we was pretty again, and said Tom plued:
# ‘’Come, for I am
# a great beautiful princes. What
# having fell neight again, and they seeip to the door, and said out to the pasks, to
# a beauu
# ----------
# bles on the glass beautifs, and drink; but she took their dear servs paragrance. The glass agree - Let she kind ouged, and that if so, and sent a chain one brow, and hear
# what he had
# done about
# their dear shook her and said, and asks being their dear
# sorrongzee me some creftly their dars of wood, doo
#
#
# Samples for epoch 5
#
#
# Unkown char: Q
# ----------
# .
# FOLNG TOLY RAPH
# RAPAEB, COck-time eggs of bread in it, and seemed they
# took their feast. Then the doors were ready for the horsemen
# to death.
# Then the maid again, and took their denerpal shook: then seeing their in very sorright along the cask.
#
# There, then he sent them. She took the night, and
# oo
# ----------
#  but got upon her knees in a ship and curioual poor children; and they could not deal
# stir vered a friendly seeing the door, and riding at all run against the
# world, and said,
# ‘’Listen there?
# ‘“ said Tom;
# ‘’if a hunberver you know? Tere thinging, you will fall smaking asks.
# ‘“ Gretel, sell
# on horss
# ----------
#  Geet softly, therefore, Snowdrop to his state of deal in
# her, and seeing nerting a huntaice, and ask her to her father, and said:
#
# ‘’Crept, bird to
# be my husbod
# time
# ‘“; and as the kitched horses, and forced to be askself
# behind the case, he had once a strange whateod away. The fowge ran asleep
# andd
# ----------
# o you.
# ‘“
# ‘’No, Pray Project Gutenberg-tm
# eleck door, she is only a good tower, and said:
# ‘’Dear hottom,
# cried out out again, if they have set full of grandmotions too, and left too you are so mick
# and crying:
# ‘’He saw a courtyous that she
# agen than their people crying for his mind men to the kinn
# ----------
# RE GIITH T ON BUCH THIS YOU DANG OR ACRAP AND URSIT TO AILENTAIT THIS WORK
#
#     TaMusl.
# ‘“ Gretel presents Hans with their father the beast read
# hig beside him
# a stwardg! I am seeklight, and did not finith it, and laid her for her with her people on the glass on their, that the dirting out of the sii
#
#
# Samples for epoch 10
#
#
# Unkown char: Q
# ----------
# ‘“ And they were
# making from the shepherd was frightenedle cudgeed at her food apishing, and had her in from another, madown their legs than she, and cut off a prince in the stars in her mouth, she went to the king had not
# for him: for 1.C behing before he went by
# kept the beautiful poing things camm
# ----------
# ve her door,
# check down and went with his dear weep open,
# and which she went and were knockdroptctios of hunger to
# eat and beautiful irounded his back. Wife, all they could not dubblational creatuage dared with
# it together nobiddy
# she was terrified:
# ‘’Fewllest combed that is going
# to see if it.
# ‘“
#
#
# ----------
# t the eldest began again.
#
# As this are seeing that the kid went on for
# peril returned to
# the renders were just nointfy mountainto fare and ask her in their dueint, who
# came to      pray Project Gutenberg-tm License from them. The little kidgreat. In the deal ever
# discoonled the door of the chamberlaa
# ----------
# nted her in the court
# berries saw a little royable with it.
# ‘’Yes,
# ‘“ said she,
# ‘’what a dear woman. I would quickly of it he begged so
# saying:
# ‘”It makes I can ness, at this, it
# lasted, but knocked at the door, and screaged a room and burned herself into a tree from the beautiful
# princesses, andd
# ----------
# ARTHESE
#
# A fursh me two
# jegerood.
# ‘“
# ‘’Where have you beautiful noundle like night, and then they crossed up their dear
# fore came to an end, and cannot have that soon coverd eyes enough to
# send a track as her stepping or disclostenly, I am rus!
# ‘“ Awake standing down in it became waking in the openn
#
#
# Samples for epoch 15
#
#
# Unkown char: Q
# ----------
# aster
# shall be seen, and uneast; and as she took her thy beautiful princess. But the third brothers.
#
# The two
# stable, as to follow ever over knocked,
# and said:
# ‘’The king was frightened and kill her why
# she arose and throwing one of the place or die. It was too sheep came, and who came to
# pasks andd
# ----------
# owdrop wagged the beautiful pairs and lighted it dispoal, they were seven long into the water,
# and said
# to Cather than that ascend himself come upon a chair and put it into paragraffect off immediately, and when she agreed the beautiful princess, and cried:
# ‘’Open the door, and need, drive her and
# ----------
#  went once not beait one another, and glittered down seein of the beautiful princess, and
# should be the doctor tree,
# ‘“ answered the old woman.
# ‘’These agen upon it?
# ‘“
# ‘’Very iman were if I am repine a lamb again from thee?
# ‘“ The possessed up sprinds asks for their hearth was shut increaing oberr
# ----------
# oor thou taken it in paragraph 1.E.1 wilt fear, he could not get over the Project Gutenberg-tm electronic works tell the Foundation, all were
# some of the
# remissally had sat a bow. And the others and gold, as to cry for her to her ever Uprison close by the top of a bund ate up to her, and called to hh
# ----------
# evants lost, then he said to her geath fellow, what wisding
# behind himself:
# ‘’When you come to a church, with such a draguined in saved a beautiful
# stock theirn small again, and was fonire, and sat
# down and son the
# duck dangran of dead, and said:
# ‘’Gretel redest.
#
#
# ‘’Yet we may get out
# of my body,,
#
#
# Samples for epoch 20
#
#
# Unkown char: Q
# ----------
# NDE IN THE OLD MADER AND PIMIS BEES OO am
# Eate!
#   And
# mouse! Do you were
# stands
# other upstairs without depal cat and ask her though like the path. He went away quite
# soon can be choking. The mother she took her that his
# great
# beasts? Then dreschanged to
# you again.
# ‘“
#
# Soon afterwards the cow--kill bb
# ----------
#  dear locaded in laws, he said she should make do you sitting open.
# ‘“ Nowlitted
# by Little King in
# their kindly of suganished
# up the deepested
# out uprist with us
# immed.
#
# Be craps to their boy:
# ‘’The rings at you think you agree you need more from the three droll on the summer
# soon came
# aclowed at tt
# ----------
# “ So he left her again they will not receive
# in it, and soon
# as the mother said,
# ‘’Elsie bread to go into
# the forest, that it daw it war soon ask alicked to see her.
# The little man coming their dear
# children, and hastened the dwarfs stripe longer, but it was a maid conding, and picking his coaling
# ----------
# h,
# ‘“ he renisted,
# ‘“ cried she;
# ‘’what is in the ever was again wait surry the askinging the door is dear
# you
# near you see
# all in loud,
# ‘“ said the cart was dard
# no
# longer enough:
# Edgear, however, then not more Hans again good once the little maiden croaked illver being) the wedding, there say atii
# ----------
# “
# ‘’The judge I
# come? Heinel come back.
# ‘“ They belonged,
# they awhere stried him the little boy placed and skipped kies
# ‘“s both subles bitted her, took a draught of his
# soldiers, as she woke up a ship felf hunger. And when it lasted at home in their
# boam unkin his eldem a bird again fall into the

# %%
model = torch.load('grimm/grimm_epoch_{}.pt'.format(1),map_location=lambda storage, loc: storage)
model
# Out:
# TextGenerationModel(
#   (lstm): LSTM(91, 128, num_layers=2, batch_first=True)
#   (out_projection): Linear(in_features=128, out_features=91, bias=True)
# )

# %%
tens = torch.empty(4).random_(4)
soft1 = torch.softmax(tens, dim=0)
soft2 = torch.softmax(soft1, dim=0)
soft3 = torch.softmax(soft2, dim=0)
print(soft1, soft2, soft3)
# Out:
# tensor([0.3995, 0.0541, 0.1470, 0.3995]) tensor([0.2870, 0.2031, 0.2229, 0.2870]) tensor([0.2592, 0.2384, 0.2432, 0.2592])
